# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))
x = layers.Dense(128*16*16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

x = layers.Conv2D(256, 5, padding = 'same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32768)             0
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

x = layers.Dropout(0.4)(x)

x = layers.Dense(1, activation = 'sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 2, 2, 128)         0
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_optimizer = keras.optimizers.RMSprop(
    lr = 0.0008,
    clipvalue = 1.0,
    decay = 1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')

# %%
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
import os
from keras.preprocessing import image

latent_dim = 32
height = 32
width = 32
channels = 3

# CIFAR10 데이터를 로드합니다
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# 개구리 이미지를 선택합니다(클래스 6)
x_train = x_train[y_train.flatten() == 6]

# 데이터를 정규화합니다
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = '/home/csle/Desktop/GAN_learing'
if not os.path.exists(save_dir):
    os.mkdir(save_dir)

# 훈련 반복 시작
start = 0
for step in range(iterations):
    # 잠재 공간에서 무작위로 포인트를 샘플링합니다
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # 가짜 이미지를 디코딩합니다
    generated_images = generator.predict(random_latent_vectors)

    # 진짜 이미지와 연결합니다
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # 진짜와 가짜 이미지를 구분하여 레이블을 합칩니다
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # 레이블에 랜덤 노이즈를 추가합니다. 아주 중요합니다!
    labels += 0.05 * np.random.random(labels.shape)

    # discriminator를 훈련합니다
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # 잠재 공간에서 무작위로 포인트를 샘플링합니다
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # 모두 “진짜 이미지"라고 레이블을 만듭니다
    misleading_targets = np.zeros((batch_size, 1))

    # generator를 훈련합니다(gan 모델에서 discriminator의 가중치는 동결됩니다)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # 중간 중간 저장하고 그래프를 그립니다
    if step % 100 == 0:
        # 모델 가중치를 저장합니다
        gan.save_weights('gan.h5')

        # 측정 지표를 출력합니다
        print('스텝 %s에서 판별자 손실: %s' % (step, d_loss))
        print('스텝 %s에서 적대적 손실: %s' % (step, a_loss))

        # 생성된 이미지 하나를 저장합니다
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # 비교를 위해 진짜 이미지 하나를 저장합니다
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# 스텝 0에서 판별자 손실: 0.46982869505882263
# 스텝 0에서 적대적 손실: 0.6568700671195984
# 스텝 100에서 판별자 손실: 10.261570930480957
# 스텝 100에서 적대적 손실: 5.517896539686262e-08
# 스텝 200에서 판별자 손실: 9.992934226989746
# 스텝 200에서 적대적 손실: 1.4693895877826435e-08
# 스텝 300에서 판별자 손실: 10.08690357208252
# 스텝 300에서 적대적 손실: 1.2073749999785832e-08
# 스텝 400에서 판별자 손실: 10.29645824432373
# 스텝 400에서 적대적 손실: 4.424745014830478e-08
# 스텝 500에서 판별자 손실: 9.766454696655273
# 스텝 500에서 적대적 손실: 2.9573788751235952e-08
# 스텝 600에서 판별자 손실: 10.22411060333252
# 스텝 600에서 적대적 손실: 9.857807015123399e-09
# 스텝 700에서 판별자 손실: 10.197320938110352
# 스텝 700에서 적대적 손실: 6.7668288750155625e-09
# 스텝 800에서 판별자 손실: 9.87458610534668
# 스텝 800에서 적대적 손실: 4.013328336327504e-08
# 스텝 900에서 판별자 손실: 10.216705322265625
# 스텝 900에서 적대적 손실: 5.749345888261814e-09
# 스텝 1000에서 판별자 손실: 10.000532150268555
# 스텝 1000에서 적대적 손실: 1.015064121645537e-08
# 스텝 1100에서 판별자 손실: 10.09953498840332
# 스텝 1100에서 적대적 손실: 1.4516450264068226e-08
# 스텝 1200에서 판별자 손실: 9.94636344909668
# 스텝 1200에서 적대적 손실: 9.841532921939233e-09
# 스텝 1300에서 판별자 손실: 10.488761901855469
# 스텝 1300에서 적대적 손실: 4.600588798808758e-09
# 스텝 1400에서 판별자 손실: 9.898428916931152
# 스텝 1400에서 적대적 손실: 1.424904372271385e-08
# 스텝 1500에서 판별자 손실: 10.31071949005127
# 스텝 1500에서 적대적 손실: 3.2208866684868553e-08
# 스텝 1600에서 판별자 손실: 10.067035675048828
# 스텝 1600에서 적대적 손실: 3.2494497759216756e-08
# 스텝 1700에서 판별자 손실: 10.310687065124512
# 스텝 1700에서 적대적 손실: 2.6878129943952445e-08
# 스텝 1800에서 판별자 손실: 10.144929885864258
# 스텝 1800에서 적대적 손실: 1.49832537488237e-08
# 스텝 1900에서 판별자 손실: 10.822755813598633
# 스텝 1900에서 적대적 손실: 4.309010392944401e-08
# 스텝 2000에서 판별자 손실: 10.572792053222656
# 스텝 2000에서 적대적 손실: 1.0777048586874116e-08
# 스텝 2100에서 판별자 손실: 10.028594970703125
# 스텝 2100에서 적대적 손실: 1.5507216843957394e-08
# 스텝 2200에서 판별자 손실: 10.784842491149902
# 스텝 2200에서 적대적 손실: 1.0505937453331171e-08
# 스텝 2300에서 판별자 손실: 10.331352233886719
# 스텝 2300에서 적대적 손실: 1.779906178001056e-08
# 스텝 2400에서 판별자 손실: 10.590832710266113
# 스텝 2400에서 적대적 손실: 1.651078385123128e-08
# 스텝 2500에서 판별자 손실: 10.166277885437012
# 스텝 2500에서 적대적 손실: 8.54991988319398e-09
# 스텝 2600에서 판별자 손실: 10.24687671661377
# 스텝 2600에서 적대적 손실: 1.7923383666129666e-08
# 스텝 2700에서 판별자 손실: 10.706903457641602
# 스텝 2700에서 적대적 손실: 1.5052156854267196e-08
# 스텝 2800에서 판별자 손실: 10.62230110168457
# 스텝 2800에서 적대적 손실: 1.744951205751022e-08
# 스텝 2900에서 판별자 손실: 10.507237434387207
# 스텝 2900에서 적대적 손실: 6.301682731191249e-09
# 스텝 3000에서 판별자 손실: 10.809392929077148
# 스텝 3000에서 적대적 손실: 5.3854044779200194e-08
# 스텝 3100에서 판별자 손실: 9.872950553894043
# 스텝 3100에서 적대적 손실: 3.673164883366553e-08
# 스텝 3200에서 판별자 손실: 10.234968185424805
# 스텝 3200에서 적대적 손실: 4.758835103757519e-09
# 스텝 3300에서 판별자 손실: 10.1245756149292
# 스텝 3300에서 적대적 손실: 5.98224758618926e-09
# 스텝 3400에서 판별자 손실: 10.306112289428711
# 스텝 3400에서 적대적 손실: 2.2200874028044382e-08
# 스텝 3500에서 판별자 손실: 10.628647804260254
# 스텝 3500에서 적대적 손실: 6.5877978627781886e-09
# 스텝 3600에서 판별자 손실: 10.256906509399414
# 스텝 3600에서 적대적 손실: 1.6593592278013602e-08
# 스텝 3700에서 판별자 손실: 10.383371353149414
# 스텝 3700에서 적대적 손실: 1.7819486330949985e-08
# 스텝 3800에서 판별자 손실: 10.388819694519043
# 스텝 3800에서 적대적 손실: 2.250692254790465e-08
# 스텝 3900에서 판별자 손실: 10.558216094970703
# 스텝 3900에서 적대적 손실: 1.0438668596179923e-08
# 스텝 4000에서 판별자 손실: 10.270536422729492
# 스텝 4000에서 적대적 손실: 9.1654470679714e-09
# 스텝 4100에서 판별자 손실: 10.109950065612793
# 스텝 4100에서 적대적 손실: 9.616193175077115e-09
# 스텝 4200에서 판별자 손실: 10.055792808532715
# 스텝 4200에서 적대적 손실: 1.3639946416788007e-07
# 스텝 4300에서 판별자 손실: 10.444621086120605
# 스텝 4300에서 적대적 손실: 7.199224771881063e-09
# 스텝 4400에서 판별자 손실: 10.318936347961426
# 스텝 4400에서 적대적 손실: 2.596427428613879e-08
# 스텝 4500에서 판별자 손실: 9.832902908325195
# 스텝 4500에서 적대적 손실: 1.5591115953839108e-08
# 스텝 4600에서 판별자 손실: 9.990911483764648
# 스텝 4600에서 적대적 손실: 6.990970913278716e-09
# 스텝 4700에서 판별자 손실: 10.473482131958008
# 스텝 4700에서 적대적 손실: 3.505176948692679e-08
# 스텝 4800에서 판별자 손실: 10.14224910736084
# 스텝 4800에서 적대적 손실: 6.561692966755572e-09
# 스텝 4900에서 판별자 손실: 10.465055465698242
# 스텝 4900에서 적대적 손실: 1.193807275257086e-08
# 스텝 5000에서 판별자 손실: 10.156030654907227
# 스텝 5000에서 적대적 손실: 4.628057492794824e-09
# 스텝 5100에서 판별자 손실: 10.299135208129883
# 스텝 5100에서 적대적 손실: 1.1979961023200758e-08
# 스텝 5200에서 판별자 손실: 10.03844928741455
# 스텝 5200에서 적대적 손실: 2.8587754385966946e-08
# 스텝 5300에서 판별자 손실: 10.260404586791992
# 스텝 5300에서 적대적 손실: 2.6613133030650715e-08
# 스텝 5400에서 판별자 손실: 10.390233039855957
# 스텝 5400에서 적대적 손실: 9.734348438428242e-09
# 스텝 5500에서 판별자 손실: 10.189621925354004
# 스텝 5500에서 적대적 손실: 6.659649720575089e-09
# 스텝 5600에서 판별자 손실: 9.868146896362305
# 스텝 5600에서 적대적 손실: 3.144027704848895e-09
# 스텝 5700에서 판별자 손실: 10.02245807647705
# 스텝 5700에서 적대적 손실: 1.0438069963925045e-08
# 스텝 5800에서 판별자 손실: 10.381573677062988
# 스텝 5800에서 적대적 손실: 3.128202408220204e-08
# 스텝 5900에서 판별자 손실: 10.13227367401123
# 스텝 5900에서 적대적 손실: 1.0831946894995781e-07
# 스텝 6000에서 판별자 손실: 10.438326835632324
# 스텝 6000에서 적대적 손실: 4.888636162547755e-09
# 스텝 6100에서 판별자 손실: 10.010614395141602
# 스텝 6100에서 적대적 손실: 3.196203124389285e-08
# 스텝 6200에서 판별자 손실: 10.394954681396484
# 스텝 6200에서 적대적 손실: 7.231775178695443e-09
# 스텝 6300에서 판별자 손실: 9.94032096862793
# 스텝 6300에서 적대적 손실: 2.2871117266731744e-07
# 스텝 6400에서 판별자 손실: 10.419258117675781
# 스텝 6400에서 적대적 손실: 5.242759115731133e-09
# 스텝 6500에서 판별자 손실: 10.141036987304688
# 스텝 6500에서 적대적 손실: 1.4218779043062568e-08
# 스텝 6600에서 판별자 손실: 10.54078483581543
# 스텝 6600에서 적대적 손실: 1.1225678164805686e-08
# 스텝 6700에서 판별자 손실: 10.657353401184082
# 스텝 6700에서 적대적 손실: 1.9048933097565168e-08
# 스텝 6800에서 판별자 손실: 10.658796310424805
# 스텝 6800에서 적대적 손실: 5.29306518615158e-08
# 스텝 6900에서 판별자 손실: 9.97790813446045
# 스텝 6900에서 적대적 손실: 1.1818130474239297e-08
# 스텝 7000에서 판별자 손실: 10.300878524780273
# 스텝 7000에서 적대적 손실: 4.44452297188036e-09
# 스텝 7100에서 판별자 손실: 10.3379545211792
# 스텝 7100에서 적대적 손실: 1.1567911073484538e-08
# 스텝 7200에서 판별자 손실: 10.315750122070312
# 스텝 7200에서 적대적 손실: 2.141759125606768e-08
# 스텝 7300에서 판별자 손실: 10.396733283996582
# 스텝 7300에서 적대적 손실: 1.1186414461406002e-08
# 스텝 7400에서 판별자 손실: 10.815399169921875
# 스텝 7400에서 적대적 손실: 1.3212586580380048e-08
# 스텝 7500에서 판별자 손실: 10.287456512451172
# 스텝 7500에서 적대적 손실: 3.1955153190210694e-08
# 스텝 7600에서 판별자 손실: 10.495210647583008
# 스텝 7600에서 적대적 손실: 1.655210368767257e-08
# 스텝 7700에서 판별자 손실: 10.494418144226074
# 스텝 7700에서 적대적 손실: 5.146028492220012e-09
# 스텝 7800에서 판별자 손실: 10.302632331848145
# 스텝 7800에서 적대적 손실: 2.0419317792175207e-08
# 스텝 7900에서 판별자 손실: 10.166671752929688
# 스텝 7900에서 적대적 손실: 6.064910706982118e-08
# 스텝 8000에서 판별자 손실: 10.326192855834961
# 스텝 8000에서 적대적 손실: 1.195122489860978e-08
# 스텝 8100에서 판별자 손실: 10.426379203796387
# 스텝 8100에서 적대적 손실: 1.1789070164525128e-08
# 스텝 8200에서 판별자 손실: 10.576864242553711
# 스텝 8200에서 적대적 손실: 1.0305618580730425e-08
# 스텝 8300에서 판별자 손실: 10.378847122192383
# 스텝 8300에서 적대적 손실: 1.2290914064294611e-08
# 스텝 8400에서 판별자 손실: 9.655390739440918
# 스텝 8400에서 적대적 손실: 4.7094168564854044e-08
# 스텝 8500에서 판별자 손실: 10.44392204284668
# 스텝 8500에서 적대적 손실: 9.306601711500662e-09
# 스텝 8600에서 판별자 손실: 10.926483154296875
# 스텝 8600에서 적대적 손실: 1.5286030219385793e-08
# 스텝 8700에서 판별자 손실: 10.64543628692627
# 스텝 8700에서 적대적 손실: 1.2309413932598545e-08
# 스텝 8800에서 판별자 손실: 10.231558799743652
# 스텝 8800에서 적대적 손실: 7.614625374685602e-09
# 스텝 8900에서 판별자 손실: 10.734712600708008
# 스텝 8900에서 적대적 손실: 5.022543714261474e-09
# 스텝 9000에서 판별자 손실: 10.427151679992676
# 스텝 9000에서 적대적 손실: 8.45528536075335e-09
# 스텝 9100에서 판별자 손실: 10.53149700164795
# 스텝 9100에서 적대적 손실: 2.5225876498780053e-08
# 스텝 9200에서 판별자 손실: 10.408927917480469
# 스텝 9200에서 적대적 손실: 2.2418083389652566e-08
# 스텝 9300에서 판별자 손실: 10.278898239135742
# 스텝 9300에서 적대적 손실: 1.3227695383477567e-08
# 스텝 9400에서 판별자 손실: 10.13261604309082
# 스텝 9400에서 적대적 손실: 6.673165131587666e-09
# 스텝 9500에서 판별자 손실: 10.138260841369629
# 스텝 9500에서 적대적 손실: 1.1807166799826518e-08
# 스텝 9600에서 판별자 손실: 10.270325660705566
# 스텝 9600에서 적대적 손실: 3.6270506598157226e-09
# 스텝 9700에서 판별자 손실: 10.087730407714844
# 스텝 9700에서 적대적 손실: 1.105607339013659e-08
# 스텝 9800에서 판별자 손실: 10.063413619995117
# 스텝 9800에서 적대적 손실: 2.2594782933538227e-08
# 스텝 9900에서 판별자 손실: 10.058097839355469
# 스텝 9900에서 적대적 손실: 1.4064188924578502e-08

# %%
discriminator.save('flog_GAN_discriminator.h5')

# %%
generator.save('flog_GAN_generator.h5')

# %%
gan.save('flog_GAN_gan.h5')

# %%
import os
from keras.preprocessing import image
import matplotlib.pyplot as plt

latent_dim = 32
height = 32
width = 32
channels = 3

# CIFAR10 데이터를 로드합니다
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# 개구리 이미지를 선택합니다(클래스 6)
x_train = x_train[y_train.flatten() == 6]

# 데이터를 정규화합니다
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.
# Out:
# (5000, 32, 32, 3)
