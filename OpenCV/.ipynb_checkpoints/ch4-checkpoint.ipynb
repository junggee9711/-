# %%
from sklearn import preprocessing
import numpy as np
X = np.array([[ 1., -2.,  2.],
              [ 3.,  0.,  0.],
              [ 0.,  1., -1.]])
binarizer = preprocessing.Binarizer(threshold = 0.5)
X_binarizer = binarizer.transform(X)
X_binarizer
# Out:
# array([[1., 0., 1.],
#        [1., 0., 0.],
#        [0., 1., 0.]])

# %%
from numpy import nan
X = np.array([[ nan, 0,   3  ],
              [ 2,   9,  -8  ],
              [ 1,   nan, 1  ],
              [ 5,   2,   4  ],
              [ 7,   6,  -3  ]])

from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy = 'median')
X2 = imp.fit_transform(X)
X2
# Out:
# array([[ 3.5,  0. ,  3. ],
#        [ 2. ,  9. , -8. ],
#        [ 1. ,  4. ,  1. ],
#        [ 5. ,  2. ,  4. ],
#        [ 7. ,  6. , -3. ]])

# %%
import numpy as np
mean = [20,20]
cov = [[5,0],[25,25]]
x, y = np.random.multivariate_normal(mean, cov, 1000).T

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

plt.plot(x, y, 'o', zorder=1)
plt.axis([0,40,0,40])
plt.xlabel('feature 1')
plt.ylabel('feature 2')
# Out:
# /home/csle/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: covariance is not positive-semidefinite.
#   after removing the cwd from sys.path.
# Text(0, 0.5, 'feature 2')

# %%
X = np.vstack((x, y)).T
import cv2
mu, eig = cv2.PCACompute(X, np.array([]))
X2 = cv2.PCAProject(X, mu, eig)
plt.plot(X2[:,0],X2[:,1],'o')
plt.axis([-20,20,-10,10])
# Out:
# (-20.0, 20.0, -10.0, 10.0)

# %%
from sklearn import decomposition
ica = decomposition.FastICA()
X2 = ica.fit_transform(X)
plt.plot(X2[:,0],X2[:,1],'o')
plt.axis([-0.2,0.2,-0.2,0.2])
# Out:
# /home/csle/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# (-0.2, 0.2, -0.2, 0.2)

# %%
nmf = decomposition.NMF()
X2 = nmf.fit_transform(X)
plt.plot(X2[:,0],X2[:,1],'o')
plt.axis([-5,15,-5,15])
# Out:
# /home/csle/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/decomposition/_nmf.py:1077: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   " improve convergence." % max_iter, ConvergenceWarning)
# (-5.0, 15.0, -5.0, 15.0)

# %%
data = [
    {'name': 'Alan Turing', 'born': 1912, 'died': 1954},
    {'name': 'Herbert A. Simon', 'born': 1916, 'died': 2001},
    {'name': 'Jacek Karpinski', 'born': 1927, 'died': 2010},
    {'name': 'J.C.R. Licklider', 'born': 1915, 'died': 1990},
    {'name': 'Marvin Minsky', 'born': 1927, 'died': 2016},
]
from sklearn.feature_extraction import DictVectorizer
vec = DictVectorizer(sparse=False, dtype=int)
vec.fit_transform(data)
# Out:
# array([[1912, 1954,    1,    0,    0,    0,    0],
#        [1916, 2001,    0,    1,    0,    0,    0],
#        [1927, 2010,    0,    0,    0,    1,    0],
#        [1915, 1990,    0,    0,    1,    0,    0],
#        [1927, 2016,    0,    0,    0,    0,    1]])

# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline
img_bgr = cv2.imread('/home/csle/Desktop/lena.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
sift = cv2.xfeatures2d.SIFT_create()
kp = sift.detect(img_bgr)

import numpy as np
img_kp = np.zeros_like(img_bgr)
img_kp = cv2.drawKeypoints(img_rgb, kp, img_kp,
flags = cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.imshow(img_kp)

# %%
kp, des = sift.compute(img_bgr, kp)
kp
# Out:
# [<KeyPoint 0x7f51aee60a80>,
#  <KeyPoint 0x7f51b7cd9b10>,
#  <KeyPoint 0x7f51b7d50630>,
#  <KeyPoint 0x7f51ae603390>,
#  <KeyPoint 0x7f51ae6034b0>,
#  <KeyPoint 0x7f51ae6037b0>,
#  <KeyPoint 0x7f51ae603e10>,
#  <KeyPoint 0x7f51ae603c60>,
#  <KeyPoint 0x7f51ae603810>,
#  <KeyPoint 0x7f51ae603ab0>,
#  <KeyPoint 0x7f51ae603a80>,
#  <KeyPoint 0x7f51ae603ba0>,
#  <KeyPoint 0x7f51ae603f90>,
#  <KeyPoint 0x7f51ae603f00>,
#  <KeyPoint 0x7f51ae7b88a0>,
#  <KeyPoint 0x7f51ae7b8810>,
#  <KeyPoint 0x7f51ae7b8840>,
#  <KeyPoint 0x7f51ae7b88d0>,
#  <KeyPoint 0x7f51ae7b8180>,
#  <KeyPoint 0x7f51ae7b8960>,
#  <KeyPoint 0x7f51ae7b8990>,
#  <KeyPoint 0x7f51ae7b89c0>,
#  <KeyPoint 0x7f51ae7b8a20>,
#  <KeyPoint 0x7f51ae7b84e0>,
#  <KeyPoint 0x7f51ae7b85d0>,
#  <KeyPoint 0x7f51ae7b8120>,
#  <KeyPoint 0x7f51ae7b8ab0>,
#  <KeyPoint 0x7f51ae7b8b10>,
#  <KeyPoint 0x7f51ae7b8ba0>,
#  <KeyPoint 0x7f51ae7b81e0>,
#  <KeyPoint 0x7f51ae7b8870>,
#  <KeyPoint 0x7f51ae7b8c00>,
#  <KeyPoint 0x7f51ae7b8c30>,
#  <KeyPoint 0x7f51ae7b8300>,
#  <KeyPoint 0x7f51ae7b8930>,
#  <KeyPoint 0x7f51ae7b8cf0>,
#  <KeyPoint 0x7f51ae7b89f0>,
#  <KeyPoint 0x7f51ae7b8d80>,
#  <KeyPoint 0x7f51ae7b8a50>,
#  <KeyPoint 0x7f51ae7b8de0>,
#  <KeyPoint 0x7f51ae7b8e10>,
#  <KeyPoint 0x7f51ae7b8b70>,
#  <KeyPoint 0x7f51ae7b8bd0>,
#  <KeyPoint 0x7f51ae7b8060>,
#  <KeyPoint 0x7f51ae7b8b40>,
#  <KeyPoint 0x7f51ae7b8210>,
#  <KeyPoint 0x7f51ae7b8f60>,
#  <KeyPoint 0x7f51ae7b8c60>,
#  <KeyPoint 0x7f51ae7b8900>,
#  <KeyPoint 0x7f51ae7b8c90>,
#  <KeyPoint 0x7f51aecd11b0>,
#  <KeyPoint 0x7f51aecd11e0>,
#  <KeyPoint 0x7f51aecd1210>,
#  <KeyPoint 0x7f51aecd1240>,
#  <KeyPoint 0x7f51aecd1270>,
#  <KeyPoint 0x7f51aecd12a0>,
#  <KeyPoint 0x7f51aecd12d0>,
#  <KeyPoint 0x7f51aecd1300>,
#  <KeyPoint 0x7f51aecd1330>,
#  <KeyPoint 0x7f51aecd1360>,
#  <KeyPoint 0x7f51aecd1390>,
#  <KeyPoint 0x7f51aecd13c0>,
#  <KeyPoint 0x7f51aecd13f0>,
#  <KeyPoint 0x7f51aecd1420>,
#  <KeyPoint 0x7f51aecd1450>,
#  <KeyPoint 0x7f51aecd1480>,
#  <KeyPoint 0x7f51aecd14b0>,
#  <KeyPoint 0x7f51aecd14e0>,
#  <KeyPoint 0x7f51aecd1510>,
#  <KeyPoint 0x7f51aecd1540>,
#  <KeyPoint 0x7f51aecd1570>,
#  <KeyPoint 0x7f51aecd15a0>,
#  <KeyPoint 0x7f51aecd15d0>,
#  <KeyPoint 0x7f51aecd1600>,
#  <KeyPoint 0x7f51aecd1630>,
#  <KeyPoint 0x7f51aecd1660>,
#  <KeyPoint 0x7f51aecd1690>,
#  <KeyPoint 0x7f51aecd16c0>,
#  <KeyPoint 0x7f51aecd16f0>,
#  <KeyPoint 0x7f51aecd1720>,
#  <KeyPoint 0x7f51aecd1750>,
#  <KeyPoint 0x7f51aecd1780>,
#  <KeyPoint 0x7f51aee8e840>,
#  <KeyPoint 0x7f51aee8e870>,
#  <KeyPoint 0x7f51aee8e8a0>,
#  <KeyPoint 0x7f51aee8e8d0>,
#  <KeyPoint 0x7f51aee8e900>,
#  <KeyPoint 0x7f51aee8e930>,
#  <KeyPoint 0x7f51aee8e960>,
#  <KeyPoint 0x7f51aee8e990>,
#  <KeyPoint 0x7f51aee8e9c0>,
#  <KeyPoint 0x7f51aee8e9f0>,
#  <KeyPoint 0x7f51aee8ea50>,
#  <KeyPoint 0x7f51aee8ea80>,
#  <KeyPoint 0x7f51aee8eab0>,
#  <KeyPoint 0x7f51aee8eae0>,
#  <KeyPoint 0x7f51aee8eb10>,
#  <KeyPoint 0x7f51aee8eb40>,
#  <KeyPoint 0x7f51aee8eb70>,
#  <KeyPoint 0x7f51aee8eba0>,
#  <KeyPoint 0x7f51aee8ebd0>,
#  <KeyPoint 0x7f51aee8ec00>,
#  <KeyPoint 0x7f51aee8ec30>,
#  <KeyPoint 0x7f51aee8ec60>,
#  <KeyPoint 0x7f51aee8ec90>,
#  <KeyPoint 0x7f51aee8ecc0>,
#  <KeyPoint 0x7f51aee8ecf0>,
#  <KeyPoint 0x7f51aee8ed20>,
#  <KeyPoint 0x7f51aee8ed50>,
#  <KeyPoint 0x7f51aee8ea20>,
#  <KeyPoint 0x7f51aee8ed80>,
#  <KeyPoint 0x7f51aee8edb0>,
#  <KeyPoint 0x7f51aee8ede0>,
#  <KeyPoint 0x7f51aee8ee10>,
#  <KeyPoint 0x7f51aee8ee40>,
#  <KeyPoint 0x7f51aee8ee70>,
#  <KeyPoint 0x7f51aee8eea0>,
#  <KeyPoint 0x7f51aee8eed0>,
#  <KeyPoint 0x7f51aee8ef00>,
#  <KeyPoint 0x7f51aee8ef30>,
#  <KeyPoint 0x7f51aee8ef60>,
#  <KeyPoint 0x7f51aee8ef90>,
#  <KeyPoint 0x7f51aee8efc0>,
#  <KeyPoint 0x7f51aee8e420>,
#  <KeyPoint 0x7f51aeccf030>,
#  <KeyPoint 0x7f51aeccf060>,
#  <KeyPoint 0x7f51aeccf090>,
#  <KeyPoint 0x7f51aeccf0c0>,
#  <KeyPoint 0x7f51aeccf0f0>,
#  <KeyPoint 0x7f51aeccf120>,
#  <KeyPoint 0x7f51aeccf150>,
#  <KeyPoint 0x7f51aeccf180>,
#  <KeyPoint 0x7f51aeccf1b0>,
#  <KeyPoint 0x7f51aeccf1e0>,
#  <KeyPoint 0x7f51aeccf210>,
#  <KeyPoint 0x7f51aeccf240>,
#  <KeyPoint 0x7f51aeccf270>,
#  <KeyPoint 0x7f51aeccf2a0>,
#  <KeyPoint 0x7f51aeccf2d0>,
#  <KeyPoint 0x7f51aeccf300>,
#  <KeyPoint 0x7f51aeccf330>,
#  <KeyPoint 0x7f51aeccf360>,
#  <KeyPoint 0x7f51aeccf390>,
#  <KeyPoint 0x7f51aeccf3c0>,
#  <KeyPoint 0x7f51aeccf3f0>,
#  <KeyPoint 0x7f51aeccf420>,
#  <KeyPoint 0x7f51aeccf450>,
#  <KeyPoint 0x7f51aeccf480>,
#  <KeyPoint 0x7f51aeccf4b0>,
#  <KeyPoint 0x7f51aeccf4e0>,
#  <KeyPoint 0x7f51aeccf510>,
#  <KeyPoint 0x7f51aeccf540>,
#  <KeyPoint 0x7f51aeccf570>,
#  <KeyPoint 0x7f51aeccf5a0>,
#  <KeyPoint 0x7f51aeccf5d0>,
#  <KeyPoint 0x7f51aeccf600>,
#  <KeyPoint 0x7f51aeccf630>,
#  <KeyPoint 0x7f51aeccf660>,
#  <KeyPoint 0x7f51aeccf690>,
#  <KeyPoint 0x7f51aeccf6c0>,
#  <KeyPoint 0x7f51aeccf6f0>,
#  <KeyPoint 0x7f51aeccf720>,
#  <KeyPoint 0x7f51aeccf750>,
#  <KeyPoint 0x7f51aeccf780>,
#  <KeyPoint 0x7f51aeccf7b0>,
#  <KeyPoint 0x7f51aeccf7e0>,
#  <KeyPoint 0x7f51aeccf810>,
#  <KeyPoint 0x7f51aeccf840>,
#  <KeyPoint 0x7f51aecd5870>,
#  <KeyPoint 0x7f51aecd58a0>,
#  <KeyPoint 0x7f51aecd58d0>]

# %%
kp2, des2 = sift.detectAndCompute(img_bgr, None)

# %%
np.allclose(des, des2)
# Out:
# True

# %%
surf = cv2.xfeatures2d.SURF_create()
kp = surf.detect(img_bgr)
img_kp = cv2.drawKeypoints(img_rgb, kp, img_kp, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.imshow(img_kp)

# %%
kp, des = surf.compute(img_bgr, kp)
des.shape
# Out:
# (351, 64)
